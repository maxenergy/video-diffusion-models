# %%
# Test 1
image_size = 128
frames = 10
max_images = 120000
batch_size = 128

# %%
# GIF pre-processing

import numpy as np
from torchvision import transforms as T
from math import floor, fabs
from PIL import Image, ImageSequence


CHANNELS_TO_MODE = {
    1 : 'L',
    3 : 'RGB',
    4 : 'RGBA'
}

def center_crop(img, new_width, new_height): 
    width = img.size[0]
    height = img.size[1]
    left = int(np.ceil((width - new_width) / 2))
    right = width - int(np.floor((width - new_width) / 2))
    top = int(np.ceil((height - new_height) / 2))
    bottom = height - int(np.floor((height - new_height) / 2))
    return img.crop((left, top, right, bottom))

def resize_crop_img(img, width, height):
    # width < height
    if( img.size[0] < img.size[1]):
      wpercent = (width/float(img.size[0]))
      hsize = int((float(img.size[1])*float(wpercent)))
      img = img.resize((width, hsize), Image.Resampling.LANCZOS)
    else: # width >= height
      hpercent = (height/float(img.size[1]))
      wsize = int((float(img.size[0])*float(hpercent)))
      img = img.resize((wsize, height), Image.Resampling.LANCZOS)
    img = center_crop(img, width, height)
    # print(img.size[0])
    # print(img.size[1])
    return img

def transform_gif(img, new_width, new_height, frames, channels = 3):
    assert channels in CHANNELS_TO_MODE, f'channels {channels} invalid'
    mode = CHANNELS_TO_MODE[channels]
    gif_frames = img.n_frames
    for i in range(0, frames):
        img.seek(i % gif_frames)
        img_out = resize_crop_img(img, new_width, new_height)
        yield img_out.convert(mode)
        
# tensor of shape (channels, frames, height, width) -> gif
def video_tensor_to_gif(tensor, path, fps = 10, loop = 0, optimize = True):
    print("Converting video tensors to GIF")
    images = map(T.ToPILImage(), tensor.unbind(dim = 1))
    first_img, *rest_imgs = images
    print(1000/fps)
    first_img.save(path, save_all = True, append_images = rest_imgs, duration = int(1000/fps), loop = loop, optimize = optimize)
    print("Gif saved")
    return images

# gif -> (channels, frame, height, width) tensor
def gif_to_tensor(path, width = 256, height = 256, frames = 32, channels = 3, transform = T.ToTensor()):
    print("Converting GIF to video tensors")
    img = Image.open(path)
    imgs = transform_gif(img, new_width = width, new_height = height, frames = frames, channels = channels)
    tensors = tuple(map(transform, imgs))
    return torch.stack(tensors, dim = 1)

# %%
import os
import torch
import shutil

train_data = "./train_data.tvs"
train_index = "./train_index.txt"

if not os.path.exists(train_data):
  # !wget -O {train_data} https://raw.githubusercontent.com/raingo/TGIF-Release/master/data/tgif-v1.0.tsv

current_index = 0
texts = []
list_videos = []

def get_videos(index_start, index_end):
    global texts
    global list_videos
    
    texts = []
    list_videos = []
    max_iter = 100

    with open("train_data.tvs") as fp:
        for i, line in enumerate(fp):
            if i >= index_start and i< index_end :
                file_img, file_text = line.split("\t")
                try:
                    print(f"Downloading image {i}");
                    # !wget -O download.gif -o /dev/null {file_img}
                    tensor = gif_to_tensor('download.gif', width = image_size, height = image_size, frames = frames)
                    list_videos.append(tensor)
                    file_text = file_text[:-1] # Remove \n
                    texts.append(file_text)
                    os.remove('download.gif')
                except Exception as ex:
                    print(ex)
                    pass
            elif i > index_end:
                break

def get_next_videos():
    global current_index
    index = 0
    if not os.path.exists(train_index):
        with open(train_index, 'w') as fp:
            fp.write("0")
    else:
        with open(train_index, 'r') as fp:
            index = int(fp.readlines()[0])
    index_end = index + batch_size
    get_videos(index, index_end)
    with open(train_index, 'w') as fp:
        fp.write(f"{index_end}")
    current_index = index_end
# Out:
# --2022-12-06 10:58:29--  https://raw.githubusercontent.com/raingo/TGIF-Release/master/data/tgif-v1.0.tsv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18660908 (18M) [text/plain]
# Saving to: ‘./train_data.tvs’
#
# ./train_data.tvs    100%[===================>]  17.80M  3.01MB/s    in 5.9s
#
# 2022-12-06 10:58:35 (3.04 MB/s) - ‘./train_data.tvs’ saved [18660908/18660908]

# %%
get_next_videos()
# Out:
# Downloading image 32
# --2022-12-06 10:09:12--  https://38.media.tumblr.com/902f71ae45f50dc0a35c04323de6495a/tumblr_nj4iqcVaFQ1s26nzro1_500.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.22, 74.114.154.18
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/902f71ae45f50dc0a35c04323de6495a/tumblr_nj4iqcVaFQ1s26nzro1_500.gif [following]
# --2022-12-06 10:09:12--  https://64.media.tumblr.com/902f71ae45f50dc0a35c04323de6495a/tumblr_nj4iqcVaFQ1s26nzro1_500.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 991818 (969K) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>] 968.57K  3.16MB/s    in 0.3s
#
# 2022-12-06 10:09:12 (3.16 MB/s) - ‘download.gif’ saved [991818/991818]
#
# Converting GIF to video tensors
# Downloading image 33
# --2022-12-06 10:09:13--  https://38.media.tumblr.com/900fe9102f650f3277c7c3d57ea095bb/tumblr_npo3mtQ87f1uxcyego1_400.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.22, 74.114.154.18
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/900fe9102f650f3277c7c3d57ea095bb/tumblr_npo3mtQ87f1uxcyego1_400.gif [following]
# --2022-12-06 10:09:13--  https://64.media.tumblr.com/900fe9102f650f3277c7c3d57ea095bb/tumblr_npo3mtQ87f1uxcyego1_400.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1326216 (1.3M) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>]   1.26M  2.77MB/s    in 0.5s
#
# 2022-12-06 10:09:13 (2.77 MB/s) - ‘download.gif’ saved [1326216/1326216]
#
# Converting GIF to video tensors
# Downloading image 34
# --2022-12-06 10:09:14--  https://38.media.tumblr.com/901288b4a1c66c58571245623bca46f9/tumblr_nqexpu1pOL1sqicm1o1_500.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.18, 74.114.154.22
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/901288b4a1c66c58571245623bca46f9/tumblr_nqexpu1pOL1sqicm1o1_500.gif [following]
# --2022-12-06 10:09:14--  https://64.media.tumblr.com/901288b4a1c66c58571245623bca46f9/tumblr_nqexpu1pOL1sqicm1o1_500.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1003973 (980K) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>] 980.44K  2.94MB/s    in 0.3s
#
# 2022-12-06 10:09:14 (2.94 MB/s) - ‘download.gif’ saved [1003973/1003973]
#
# Converting GIF to video tensors
# Downloading image 35
# --2022-12-06 10:09:15--  https://38.media.tumblr.com/8f53c46d4e2a40bc8dfc458fbd145cf1/tumblr_nq541zHa5n1uy63pco1_r1_250.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.22, 74.114.154.18
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/8f53c46d4e2a40bc8dfc458fbd145cf1/tumblr_nq541zHa5n1uy63pco1_r1_250.gif [following]
# --2022-12-06 10:09:15--  https://64.media.tumblr.com/8f53c46d4e2a40bc8dfc458fbd145cf1/tumblr_nq541zHa5n1uy63pco1_r1_250.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1258408 (1.2M) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>]   1.20M  1.75MB/s    in 0.7s
#
# 2022-12-06 10:09:15 (1.75 MB/s) - ‘download.gif’ saved [1258408/1258408]
#
# Converting GIF to video tensors
# Downloading image 36
# --2022-12-06 10:09:16--  https://38.media.tumblr.com/8fb23a0c630d559029d1ed77a9a5959e/tumblr_nnxshbEKOc1rqd7uco1_500.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.22, 74.114.154.18
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/8fb23a0c630d559029d1ed77a9a5959e/tumblr_nnxshbEKOc1rqd7uco1_500.gif [following]
# --2022-12-06 10:09:16--  https://64.media.tumblr.com/8fb23a0c630d559029d1ed77a9a5959e/tumblr_nnxshbEKOc1rqd7uco1_500.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1316118 (1.3M) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>]   1.25M  2.98MB/s    in 0.4s
#
# 2022-12-06 10:09:16 (2.98 MB/s) - ‘download.gif’ saved [1316118/1316118]
#
# Converting GIF to video tensors
# Downloading image 37
# --2022-12-06 10:09:17--  https://38.media.tumblr.com/8f5884647e1aaa0bda5677fbefec7ed4/tumblr_nq8ajiaBT71usj03ho1_500.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.18, 74.114.154.22
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/8f5884647e1aaa0bda5677fbefec7ed4/tumblr_nq8ajiaBT71usj03ho1_500.gif [following]
# --2022-12-06 10:09:17--  https://64.media.tumblr.com/8f5884647e1aaa0bda5677fbefec7ed4/tumblr_nq8ajiaBT71usj03ho1_500.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 847687 (828K) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>] 827.82K  3.56MB/s    in 0.2s
#
# 2022-12-06 10:09:17 (3.56 MB/s) - ‘download.gif’ saved [847687/847687]
#
# Converting GIF to video tensors
# Downloading image 38
# --2022-12-06 10:09:18--  https://38.media.tumblr.com/8bf7c993adf5ba5ecea8ed946f8eb10e/tumblr_np5x4gNc1L1ux4ymjo1_500.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.18, 74.114.154.22
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/8bf7c993adf5ba5ecea8ed946f8eb10e/tumblr_np5x4gNc1L1ux4ymjo1_500.gif [following]
# --2022-12-06 10:09:18--  https://64.media.tumblr.com/8bf7c993adf5ba5ecea8ed946f8eb10e/tumblr_np5x4gNc1L1ux4ymjo1_500.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1110390 (1.1M) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>]   1.06M  2.13MB/s    in 0.5s
#
# 2022-12-06 10:09:18 (2.13 MB/s) - ‘download.gif’ saved [1110390/1110390]
#
# Converting GIF to video tensors
# Downloading image 39
# --2022-12-06 10:09:19--  https://38.media.tumblr.com/8c4ee5c0338ad534042e85605b70c927/tumblr_npqraj6f5R1uuxd1yo1_500.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.22, 74.114.154.18
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/8c4ee5c0338ad534042e85605b70c927/tumblr_npqraj6f5R1uuxd1yo1_500.gif [following]
# --2022-12-06 10:09:19--  https://64.media.tumblr.com/8c4ee5c0338ad534042e85605b70c927/tumblr_npqraj6f5R1uuxd1yo1_500.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1273448 (1.2M) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>]   1.21M  3.07MB/s    in 0.4s
#
# 2022-12-06 10:09:19 (3.07 MB/s) - ‘download.gif’ saved [1273448/1273448]
#
# Converting GIF to video tensors
# Downloading image 40
# --2022-12-06 10:09:20--  https://38.media.tumblr.com/8b67dd69640e5b12d55fdd8257319782/tumblr_no2up3t1Bv1usegjto1_250.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.18, 74.114.154.22
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/8b67dd69640e5b12d55fdd8257319782/tumblr_no2up3t1Bv1usegjto1_250.gif [following]
# --2022-12-06 10:09:20--  https://64.media.tumblr.com/8b67dd69640e5b12d55fdd8257319782/tumblr_no2up3t1Bv1usegjto1_250.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1905586 (1.8M) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>]   1.82M  4.39MB/s    in 0.4s
#
# 2022-12-06 10:09:21 (4.39 MB/s) - ‘download.gif’ saved [1905586/1905586]
#
# Converting GIF to video tensors
# Downloading image 41
# --2022-12-06 10:09:21--  https://38.media.tumblr.com/8c90113076757a48a25a53942d829b02/tumblr_nl77cuGZWn1sm50zqo1_400.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.22, 74.114.154.18
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/8c90113076757a48a25a53942d829b02/tumblr_nl77cuGZWn1sm50zqo1_400.gif [following]
# --2022-12-06 10:09:21--  https://64.media.tumblr.com/8c90113076757a48a25a53942d829b02/tumblr_nl77cuGZWn1sm50zqo1_400.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 904514 (883K) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>] 883.31K  3.61MB/s    in 0.2s
#
# 2022-12-06 10:09:21 (3.61 MB/s) - ‘download.gif’ saved [904514/904514]
#
# Converting GIF to video tensors
# Downloading image 42
# --2022-12-06 10:09:22--  https://38.media.tumblr.com/8beac80e7df8b66fc5d50d9f0679c527/tumblr_nnn5873T0c1uqclqmo1_500.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.22, 74.114.154.18
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/8beac80e7df8b66fc5d50d9f0679c527/tumblr_nnn5873T0c1uqclqmo1_500.gif [following]
# --2022-12-06 10:09:22--  https://64.media.tumblr.com/8beac80e7df8b66fc5d50d9f0679c527/tumblr_nnn5873T0c1uqclqmo1_500.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862500 (842K) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>] 842.29K  3.42MB/s    in 0.2s
#
# 2022-12-06 10:09:22 (3.42 MB/s) - ‘download.gif’ saved [862500/862500]
#
# Converting GIF to video tensors
# Downloading image 43
# --2022-12-06 10:09:23--  https://38.media.tumblr.com/8bf3197a0c9d0218d2fef5b428d2c143/tumblr_nowg4sfk6D1qzefc2o1_400.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.18, 74.114.154.22
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/8bf3197a0c9d0218d2fef5b428d2c143/tumblr_nowg4sfk6D1qzefc2o1_400.gif [following]
# --2022-12-06 10:09:23--  https://64.media.tumblr.com/8bf3197a0c9d0218d2fef5b428d2c143/tumblr_nowg4sfk6D1qzefc2o1_400.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 964697 (942K) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>] 942.09K  3.08MB/s    in 0.3s
#
# 2022-12-06 10:09:24 (3.08 MB/s) - ‘download.gif’ saved [964697/964697]
#
# Converting GIF to video tensors
# Downloading image 44
# --2022-12-06 10:09:24--  https://38.media.tumblr.com/8b7e9aa41d080e9141a6f32fa4e7bbdc/tumblr_nohp6gAaLv1si7d5lo1_400.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.22, 74.114.154.18
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/8b7e9aa41d080e9141a6f32fa4e7bbdc/tumblr_nohp6gAaLv1si7d5lo1_400.gif [following]
# --2022-12-06 10:09:25--  https://64.media.tumblr.com/8b7e9aa41d080e9141a6f32fa4e7bbdc/tumblr_nohp6gAaLv1si7d5lo1_400.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 391641 (382K) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>] 382.46K  1.82MB/s    in 0.2s
#
# 2022-12-06 10:09:25 (1.82 MB/s) - ‘download.gif’ saved [391641/391641]
#
# Converting GIF to video tensors
# Downloading image 45
# --2022-12-06 10:09:25--  https://38.media.tumblr.com/8cd34a2a68232f097b85f1839a2fd7a3/tumblr_npgxznNRd31uv0y2ro1_250.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.22, 74.114.154.18
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/8cd34a2a68232f097b85f1839a2fd7a3/tumblr_npgxznNRd31uv0y2ro1_250.gif [following]
# --2022-12-06 10:09:25--  https://64.media.tumblr.com/8cd34a2a68232f097b85f1839a2fd7a3/tumblr_npgxznNRd31uv0y2ro1_250.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1520007 (1.4M) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>]   1.45M  3.33MB/s    in 0.4s
#
# 2022-12-06 10:09:26 (3.33 MB/s) - ‘download.gif’ saved [1520007/1520007]
#
# Converting GIF to video tensors
# Downloading image 46
# --2022-12-06 10:09:26--  https://38.media.tumblr.com/8cd949e726a9ec15950a4f4cda4eb330/tumblr_nq789eiheZ1r3kmkso1_1280.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.22, 74.114.154.18
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/8cd949e726a9ec15950a4f4cda4eb330/tumblr_nq789eiheZ1r3kmkso1_1280.gif [following]
# --2022-12-06 10:09:26--  https://64.media.tumblr.com/8cd949e726a9ec15950a4f4cda4eb330/tumblr_nq789eiheZ1r3kmkso1_1280.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1625160 (1.5M) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>]   1.55M  3.59MB/s    in 0.4s
#
# 2022-12-06 10:09:27 (3.59 MB/s) - ‘download.gif’ saved [1625160/1625160]
#
# Converting GIF to video tensors
# Downloading image 47
# --2022-12-06 10:09:28--  https://38.media.tumblr.com/8c572ffffaad8065e52d3235bd0146b5/tumblr_nqrlhsLD931uzihc0o1_500.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.22, 74.114.154.18
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/8c572ffffaad8065e52d3235bd0146b5/tumblr_nqrlhsLD931uzihc0o1_500.gif [following]
# --2022-12-06 10:09:28--  https://64.media.tumblr.com/8c572ffffaad8065e52d3235bd0146b5/tumblr_nqrlhsLD931uzihc0o1_500.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 503311 (492K) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>] 491.51K  2.41MB/s    in 0.2s
#
# 2022-12-06 10:09:28 (2.41 MB/s) - ‘download.gif’ saved [503311/503311]
#
# Converting GIF to video tensors
# Downloading image 48
# --2022-12-06 10:09:28--  https://38.media.tumblr.com/8cc0d8b94f1694a74f8754de3934ae2d/tumblr_nqir72vsUx1sd7dido1_500.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.18, 74.114.154.22
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/8cc0d8b94f1694a74f8754de3934ae2d/tumblr_nqir72vsUx1sd7dido1_500.gif [following]
# --2022-12-06 10:09:28--  https://64.media.tumblr.com/8cc0d8b94f1694a74f8754de3934ae2d/tumblr_nqir72vsUx1sd7dido1_500.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1043302 (1019K) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>]   1019K  3.10MB/s    in 0.3s
#
# 2022-12-06 10:09:29 (3.10 MB/s) - ‘download.gif’ saved [1043302/1043302]
#
# Converting GIF to video tensors
# Downloading image 49
# --2022-12-06 10:09:30--  https://38.media.tumblr.com/8cc0d8b94f1694a74f8754de3934ae2d/tumblr_nqir72vsUx1sd7dido1_500.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.22, 74.114.154.18
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/8cc0d8b94f1694a74f8754de3934ae2d/tumblr_nqir72vsUx1sd7dido1_500.gif [following]
# --2022-12-06 10:09:30--  https://64.media.tumblr.com/8cc0d8b94f1694a74f8754de3934ae2d/tumblr_nqir72vsUx1sd7dido1_500.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1043302 (1019K) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>]   1019K  3.28MB/s    in 0.3s
#
# 2022-12-06 10:09:30 (3.28 MB/s) - ‘download.gif’ saved [1043302/1043302]
#
# Converting GIF to video tensors
# Downloading image 50
# --2022-12-06 10:09:31--  https://38.media.tumblr.com/8bb63b757c40c499d2eccb9a2910d57b/tumblr_mgq9bwHRA51rhzq0oo1_500.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.22, 74.114.154.18
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/8bb63b757c40c499d2eccb9a2910d57b/tumblr_mgq9bwHRA51rhzq0oo1_500.gif [following]
# --2022-12-06 10:09:31--  https://64.media.tumblr.com/8bb63b757c40c499d2eccb9a2910d57b/tumblr_mgq9bwHRA51rhzq0oo1_500.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 986938 (964K) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>] 963.81K  3.90MB/s    in 0.2s
#
# 2022-12-06 10:09:31 (3.90 MB/s) - ‘download.gif’ saved [986938/986938]
#
# Converting GIF to video tensors
# Downloading image 51
# --2022-12-06 10:09:31--  https://38.media.tumblr.com/8b8c94e0279cc6d2775ae08e0853f823/tumblr_nq5nstjatI1u1lytfo1_250.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.18, 74.114.154.22
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/8b8c94e0279cc6d2775ae08e0853f823/tumblr_nq5nstjatI1u1lytfo1_250.gif [following]
# --2022-12-06 10:09:31--  https://64.media.tumblr.com/8b8c94e0279cc6d2775ae08e0853f823/tumblr_nq5nstjatI1u1lytfo1_250.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 741622 (724K) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>] 724.24K  2.39MB/s    in 0.3s
#
# 2022-12-06 10:09:32 (2.39 MB/s) - ‘download.gif’ saved [741622/741622]
#
# Converting GIF to video tensors
# Downloading image 52
# --2022-12-06 10:09:32--  https://38.media.tumblr.com/8c14aa571911985d6d774762f8159452/tumblr_n4gk7efcMw1spy7ono1_400.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.22, 74.114.154.18
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/8c14aa571911985d6d774762f8159452/tumblr_n4gk7efcMw1spy7ono1_400.gif [following]
# --2022-12-06 10:09:32--  https://64.media.tumblr.com/8c14aa571911985d6d774762f8159452/tumblr_n4gk7efcMw1spy7ono1_400.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 913069 (892K) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>] 891.67K  3.17MB/s    in 0.3s
#
# 2022-12-06 10:09:33 (3.17 MB/s) - ‘download.gif’ saved [913069/913069]
#
# Converting GIF to video tensors
# Downloading image 53
# --2022-12-06 10:09:33--  https://38.media.tumblr.com/8cd3ac9b6db79b6fb1f52961bb173276/tumblr_nogx44forU1swlz57o1_500.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.22, 74.114.154.18
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/8cd3ac9b6db79b6fb1f52961bb173276/tumblr_nogx44forU1swlz57o1_500.gif [following]
# --2022-12-06 10:09:33--  https://64.media.tumblr.com/8cd3ac9b6db79b6fb1f52961bb173276/tumblr_nogx44forU1swlz57o1_500.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 969252 (947K) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>] 946.54K  3.61MB/s    in 0.3s
#
# 2022-12-06 10:09:33 (3.61 MB/s) - ‘download.gif’ saved [969252/969252]
#
# Converting GIF to video tensors
# Downloading image 54
# --2022-12-06 10:09:34--  https://38.media.tumblr.com/70f4c1fc63e69bafb2c0aafcc293d6ff/tumblr_npc3iyfpDC1ux3xido1_400.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.18, 74.114.154.22
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/70f4c1fc63e69bafb2c0aafcc293d6ff/tumblr_npc3iyfpDC1ux3xido1_400.gif [following]
# --2022-12-06 10:09:34--  https://64.media.tumblr.com/70f4c1fc63e69bafb2c0aafcc293d6ff/tumblr_npc3iyfpDC1ux3xido1_400.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1359775 (1.3M) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>]   1.30M  3.49MB/s    in 0.4s
#
# 2022-12-06 10:09:35 (3.49 MB/s) - ‘download.gif’ saved [1359775/1359775]
#
# Converting GIF to video tensors
# Downloading image 55
# --2022-12-06 10:09:35--  https://38.media.tumblr.com/70f2b88e7ef089a5d8d3722dfceb1e55/tumblr_n8tb4xoSOr1sxfqdyo1_1280.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.22, 74.114.154.18
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/70f2b88e7ef089a5d8d3722dfceb1e55/tumblr_n8tb4xoSOr1sxfqdyo1_1280.gif [following]
# --2022-12-06 10:09:35--  https://64.media.tumblr.com/70f2b88e7ef089a5d8d3722dfceb1e55/tumblr_n8tb4xoSOr1sxfqdyo1_1280.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1929293 (1.8M) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>]   1.84M  3.94MB/s    in 0.5s
#
# 2022-12-06 10:09:36 (3.94 MB/s) - ‘download.gif’ saved [1929293/1929293]
#
# Converting GIF to video tensors
# Downloading image 56
# --2022-12-06 10:09:36--  https://38.media.tumblr.com/6f8901961aa2ff3f85a105e844ced445/tumblr_nq2px77Scz1uycuzco1_500.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.22, 74.114.154.18
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/6f8901961aa2ff3f85a105e844ced445/tumblr_nq2px77Scz1uycuzco1_500.gif [following]
# --2022-12-06 10:09:36--  https://64.media.tumblr.com/6f8901961aa2ff3f85a105e844ced445/tumblr_nq2px77Scz1uycuzco1_500.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1313803 (1.3M) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>]   1.25M  3.23MB/s    in 0.4s
#
# 2022-12-06 10:09:37 (3.23 MB/s) - ‘download.gif’ saved [1313803/1313803]
#
# Converting GIF to video tensors
# Downloading image 57
# --2022-12-06 10:09:37--  https://38.media.tumblr.com/70af581598a20a1af31773cdab4b0321/tumblr_mxp686hce71sqec3to1_500.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.18, 74.114.154.22
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/70af581598a20a1af31773cdab4b0321/tumblr_mxp686hce71sqec3to1_500.gif [following]
# --2022-12-06 10:09:37--  https://64.media.tumblr.com/70af581598a20a1af31773cdab4b0321/tumblr_mxp686hce71sqec3to1_500.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 486869 (475K) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>] 475.46K  1.88MB/s    in 0.2s
#
# 2022-12-06 10:09:37 (1.88 MB/s) - ‘download.gif’ saved [486869/486869]
#
# Converting GIF to video tensors
# Downloading image 58
# --2022-12-06 10:09:38--  https://38.media.tumblr.com/6ff9ef1e816fed43fcf7e2f2498e1349/tumblr_nl33vmyhNi1u9vl8lo1_400.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.22, 74.114.154.18
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/6ff9ef1e816fed43fcf7e2f2498e1349/tumblr_nl33vmyhNi1u9vl8lo1_400.gif [following]
# --2022-12-06 10:09:38--  https://64.media.tumblr.com/6ff9ef1e816fed43fcf7e2f2498e1349/tumblr_nl33vmyhNi1u9vl8lo1_400.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2092546 (2.0M) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>]   2.00M  3.68MB/s    in 0.5s
#
# 2022-12-06 10:09:39 (3.68 MB/s) - ‘download.gif’ saved [2092546/2092546]
#
# Converting GIF to video tensors
# Downloading image 59
# --2022-12-06 10:09:39--  https://38.media.tumblr.com/712368408b70ce32ee4eb0f9f6fe6639/tumblr_noxlpdet5k1uwrtyko1_500.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.22, 74.114.154.18
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/712368408b70ce32ee4eb0f9f6fe6639/tumblr_noxlpdet5k1uwrtyko1_500.gif [following]
# --2022-12-06 10:09:39--  https://64.media.tumblr.com/712368408b70ce32ee4eb0f9f6fe6639/tumblr_noxlpdet5k1uwrtyko1_500.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1048630 (1.0M) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>]   1.00M  3.94MB/s    in 0.3s
#
# 2022-12-06 10:09:39 (3.94 MB/s) - ‘download.gif’ saved [1048630/1048630]
#
# Converting GIF to video tensors
# Downloading image 60
# --2022-12-06 10:09:40--  https://38.media.tumblr.com/712368408b70ce32ee4eb0f9f6fe6639/tumblr_noxlpdet5k1uwrtyko1_500.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.22, 74.114.154.18
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/712368408b70ce32ee4eb0f9f6fe6639/tumblr_noxlpdet5k1uwrtyko1_500.gif [following]
# --2022-12-06 10:09:40--  https://64.media.tumblr.com/712368408b70ce32ee4eb0f9f6fe6639/tumblr_noxlpdet5k1uwrtyko1_500.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1048630 (1.0M) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>]   1.00M  1.15MB/s    in 0.9s
#
# 2022-12-06 10:09:41 (1.15 MB/s) - ‘download.gif’ saved [1048630/1048630]
#
# Converting GIF to video tensors
# Downloading image 61
# --2022-12-06 10:09:42--  https://38.media.tumblr.com/709628e0cae3704db3eae23d10695d67/tumblr_nntf25N0Fx1uu6kufo1_250.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.18, 74.114.154.22
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/709628e0cae3704db3eae23d10695d67/tumblr_nntf25N0Fx1uu6kufo1_250.gif [following]
# --2022-12-06 10:09:42--  https://64.media.tumblr.com/709628e0cae3704db3eae23d10695d67/tumblr_nntf25N0Fx1uu6kufo1_250.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 861313 (841K) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>] 841.13K  2.38MB/s    in 0.3s
#
# 2022-12-06 10:09:42 (2.38 MB/s) - ‘download.gif’ saved [861313/861313]
#
# Converting GIF to video tensors
# Downloading image 62
# --2022-12-06 10:09:43--  https://38.media.tumblr.com/708a8a33362c8b2548c5b9a09463da49/tumblr_mtbdvn6y1D1rjj5sho1_400.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.22, 74.114.154.18
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.22|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/708a8a33362c8b2548c5b9a09463da49/tumblr_mtbdvn6y1D1rjj5sho1_400.gif [following]
# --2022-12-06 10:09:43--  https://64.media.tumblr.com/708a8a33362c8b2548c5b9a09463da49/tumblr_mtbdvn6y1D1rjj5sho1_400.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 459355 (449K) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>] 448.59K  1.66MB/s    in 0.3s
#
# 2022-12-06 10:09:43 (1.66 MB/s) - ‘download.gif’ saved [459355/459355]
#
# Converting GIF to video tensors
# Downloading image 63
# --2022-12-06 10:09:44--  https://38.media.tumblr.com/6fb91b85be51fd128be592d4618b6cf7/tumblr_noco9fFCqL1rpe4qfo1_500.gif
# Resolving 38.media.tumblr.com (38.media.tumblr.com)... 74.114.154.18, 74.114.154.22
# Connecting to 38.media.tumblr.com (38.media.tumblr.com)|74.114.154.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://64.media.tumblr.com/6fb91b85be51fd128be592d4618b6cf7/tumblr_noco9fFCqL1rpe4qfo1_500.gif [following]
# --2022-12-06 10:09:44--  https://64.media.tumblr.com/6fb91b85be51fd128be592d4618b6cf7/tumblr_noco9fFCqL1rpe4qfo1_500.gif
# Resolving 64.media.tumblr.com (64.media.tumblr.com)... 192.0.77.3
# Connecting to 64.media.tumblr.com (64.media.tumblr.com)|192.0.77.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1048315 (1024K) [image/gif]
# Saving to: ‘download.gif’
#
# download.gif        100%[===================>]   1024K  2.82MB/s    in 0.4s
#
# 2022-12-06 10:09:44 (2.82 MB/s) - ‘download.gif’ saved [1048315/1048315]
#
# Converting GIF to video tensors

# %%
import shutil
import torch
import datetime
import gc
from imagen_pytorch import Unet3D, ElucidatedImagen, ImagenTrainer
from imagen_pytorch.data import Dataset

checkpoints_path = "./checkpoints"
if not os.path.exists(checkpoints_path):
    os.mkdir(checkpoints_path)

last_checkpoint_path = os.path.join(checkpoints_path, "last_checkpoint.txt")
num_saves = 0

def save_checkpoint(trainer: ImagenTrainer, unet, step):
    print("Saving checkpoint")
    current_datetime = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    new_checkpoint_path = os.path.join(checkpoints_path, f"checkpoint-unet{unet}-step{step}-{current_datetime}.pt")
    trainer.save(new_checkpoint_path)
    if os.path.exists(last_checkpoint_path):
        with open(last_checkpoint_path, 'r') as fp:
            os.remove(fp.readlines()[0])
    with open(last_checkpoint_path, 'w') as fp:
        fp.write(new_checkpoint_path)
    global num_saves
    num_saves += 1
    with open("num_saves.txt", 'w') as fp:
        fp.write(f"{num_saves}")

def load_checkpoint(trainer: ImagenTrainer):
    if not os.path.exists(last_checkpoint_path):
        return None
    with open(last_checkpoint_path, 'r') as fp:
        checkpoint_path = fp.readlines()[0]
    try:
        print("Loading checkpoint")
        trainer.load(checkpoint_path)
    except:
        return None
# Out:
# Downloading:   0%|          | 0.00/605 [00:00<?, ?B/s]
# /usr/local/lib/python3.9/dist-packages/beartype/_util/hint/pep/utilpeptest.py:345: BeartypeDecorHintPep585DeprecationWarning: PEP 484 type hint typing.List[str] deprecated by PEP 585 scheduled for removal in the first Python version released after October 5th, 2025. To resolve this, import this hint from "beartype.typing" rather than "typing". See this discussion for further details and alternatives:
#     https://github.com/beartype/beartype#pep-585-deprecations
#   warn(

# %%
unet1 = None
unet2 = None
imagen = None
trainer = None

def setup_trainer():
    global unet1
    global unet2
    global imagen
    global trainer
    
    unet1 = Unet3D(
        dim = 64,
        cond_dim = 128,
        dim_mults = (1, 2, 4, 8),
        num_resnet_blocks = 3,
        layer_attns = (False, True, True, True),
        layer_cross_attns = (False, True, True, True)
    )

    unet2 = Unet3D(
        dim = 64,
        cond_dim = 128,
        dim_mults = (1, 2, 4, 8),
        num_resnet_blocks = (2, 4, 8, 8),
        layer_attns = (False, False, False, True),
        layer_cross_attns = (False, False, False, True)
    )

    imagen = ElucidatedImagen(
        unets = (unet1, unet2),
        image_sizes = (16, 32),
        random_crop_sizes = (None, 16),
        num_sample_steps = 10,
        # timesteps = 1000,
        cond_drop_prob = 0.1,                       # gives the probability of dropout for classifier-free guidance.
        sigma_min = 0.002,                          # min noise level
        sigma_max = (80, 160),                      # max noise level, double the max noise level for upsampler
        sigma_data = 0.5,                           # standard deviation of data distribution
        rho = 7,                                    # controls the sampling schedule
        P_mean = -1.2,                              # mean of log-normal distribution from which noise is drawn for training
        P_std = 1.2,                                # standard deviation of log-normal distribution from which noise is drawn for training
        S_churn = 80,                               # parameters for stochastic sampling - depends on dataset, Table 5 in apper
        S_tmin = 0.05,
        S_tmax = 50,
        S_noise = 1.003,
    ).cuda()

    trainer = ImagenTrainer(imagen)

def free_trainer():
    global unet1
    global unet2
    global imagen
    global trainer
    del unet1
    del unet2
    del imagen
    del trainer
    gc.collect()
    torch.cuda.empty_cache()

# %%
# unet1 = Unet3D(dim = 128, dim_mults = (1, 2, 4, 8)).cuda()
# unet2 = Unet3D(dim = 128, dim_mults = (1, 2, 4, 8)).cuda()

# imagen = ElucidatedImagen(
#     unets = (unet1, unet2),
#     image_sizes = (16, 32),
#     random_crop_sizes = (None, 16),
#     num_sample_steps = 10,
#     cond_drop_prob = 0.1,
#     sigma_min = 0.002,                          # min noise level
#     sigma_max = (80, 160),                      # max noise level, double the max noise level for upsampler
#     sigma_data = 0.5,                           # standard deviation of data distribution
#     rho = 7,                                    # controls the sampling schedule
#     P_mean = -1.2,                              # mean of log-normal distribution from which noise is drawn for training
#     P_std = 1.2,                                # standard deviation of log-normal distribution from which noise is drawn for training
#     S_churn = 80,                               # parameters for stochastic sampling - depends on dataset, Table 5 in apper
#     S_tmin = 0.05,
#     S_tmax = 50,
#     S_noise = 1.003,
# ).cuda()

# %%
# Train Unets

# batch_size = 512
# get_next_videos()
for unet in range(1, 3):
    print(f"Training unet {unet}")
    videos = torch.stack(list_videos, dim = 0).cuda()
    setup_trainer()
    load_checkpoint(trainer)
    trainer(videos, texts = texts, unet_number = unet, max_batch_size = 32)
    trainer.update(unet_number = unet)
    save_checkpoint(trainer, unet, current_index)
    del videos
    free_trainer()
# Out:
# Training unet 1
# Downloading:   0%|          | 0.00/945M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/773k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.74k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.81k [00:00<?, ?B/s]
# Saving checkpoint
# checkpoint saved to ./checkpoints/checkpoint-unet1-step512-20221206-115138.pt
# Training unet 2
# Loading checkpoint
# checkpoint loaded from ./checkpoints/checkpoint-unet1-step512-20221206-115138.pt
# Saving checkpoint
# checkpoint saved to ./checkpoints/checkpoint-unet2-step512-20221206-115247.pt

# %%
# Train Unet 2
unet_number = 2
videos = torch.stack(list_videos, dim = 0).cuda()
setup_trainer()
load_checkpoint(trainer)

print(videos.shape)
print(len(texts))

trainer(videos, texts = texts, unet_number = unet_number, max_batch_size = 32)
trainer.update(unet_number = unet_number)
save_checkpoint(trainer, unet_number, current_index)
del videos
free_trainer()
# Out:
# checkpoint loaded from ./checkpoints/checkpoint-unet1-step64-20221206-101018.pt
# Loaded checkpoint
# torch.Size([32, 3, 10, 128, 128])
# 32
# Saving checkpoint
# checkpoint saved to ./checkpoints/checkpoint-unet2-step64-20221206-101110.pt

# %%
# !pip install GPUtil

# from GPUtil import showUtilization as gpu_usage
# gpu_usage()

# %%
# Train Unet 2

# trainer = ImagenTrainer(imagen)
# trainer(videos, texts = texts, unet_number = 2, max_batch_size = 1)
# trainer.update(unet_number = 2)

# %%
#end
